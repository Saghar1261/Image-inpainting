# %% [markdown]
# ### GAN

# %% [markdown]
# This section imports necessary libraries and modules for the implementation. Notable libraries include NumPy for numerical operations, Matplotlib for plotting, TensorFlow and Keras for deep learning, and others for image processing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, BatchNormalization, Activation, LeakyReLU, Concatenate
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy, MeanSquaredError
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras import backend as K
import os
from PIL import UnidentifiedImageError
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.models import Model as KerasModel
from tensorflow.keras.preprocessing import image
from scipy.linalg import sqrtm
from skimage.metrics import peak_signal_noise_ratio, structural_similarity
from skimage.transform import resize

# %% [markdown]
# Setting a random seed ensures that the random initialization of weights and other random processes in the code is reproducible.

# %%
# Set the seed for reproducibility
np.random.seed(1000)

# %% [markdown]
# Define Image Parameters:
#
# These parameters define the size and shape of the images, the size of the noise vector (z_dim), the number of training epochs, batch size, and the interval at which to save generated images during training.

# %%
# Define image parameters
img_rows, img_cols, channels = 128, 128, 3
img_shape = (img_rows, img_cols, channels)
z_dim = 100  # Size of the noise vector
epochs = 1000
batch_size = 128
save_interval = 100  # Set the interval to save generated images

# %% [markdown]
# Function to Save Generated Images:
#
# This function takes the current epoch, generator model, paths to undamaged and damaged test images, and saves a set of generated images for visualization.

# %%
# Function to save generated images
def save_generated_images(epoch, generator, output_path, X_test_undamaged, X_test_damaged, z_dim=100, r=5, c=3):
    # Resize images to match the repair generator input shape
    X_test_undamaged_resized = np.array([resize(img, (128, 128, 3), mode='reflect', anti_aliasing=True) for img in X_test_undamaged])
    X_test_damaged_resized = np.array([resize(img, (128, 128, 3), mode='reflect', anti_aliasing=True) for img in X_test_damaged])

    # Generate repaired images for damaged parts
    repaired_imgs = generator.predict([X_test_undamaged_resized, X_test_damaged_resized])

    # Identify damaged regions based on pixel differences
    damaged_regions = np.sum(np.abs(X_test_undamaged_resized - X_test_damaged_resized), axis=-1) > 50

    # Copy repaired parts to damaged images
    for i in range(len(X_test_undamaged_resized)):
        X_test_damaged_resized[i][damaged_regions[i]] = repaired_imgs[i][damaged_regions[i]]

    # Rescale images to 0-1
    X_test_undamaged_rescaled = 0.5 * (X_test_undamaged_resized + 1)
    X_test_damaged_rescaled = 0.5 * (X_test_damaged_resized + 1)

    fig, axs = plt.subplots(r, c, figsize=(15, 15))
    cnt = 0
    for i in range(r):
        axs[i, 0].imshow(X_test_undamaged_rescaled[cnt])
        axs[i, 0].axis('off')
        axs[i, 0].set_title("Real (Undamaged)")

        axs[i, 1].imshow(X_test_damaged_rescaled[cnt])
        axs[i, 1].axis('off')
        axs[i, 1].set_title("Damaged")

        axs[i, 2].imshow(repaired_imgs[cnt])
        axs[i, 2].axis('off')
        axs[i, 2].set_title("Repaired")

        cnt += 1

    fig.savefig(output_path + f"/gan_repaired_image_epoch_{epoch}.png")
    plt.close()

# %% [markdown]
# This function defines and returns a repair generator model, which takes undamaged and damaged images as input and aims to generate a repaired image.

# %%
def build_repair_generator(z_dim=100):
    undamaged_input = Input(shape=img_shape, name='undamaged_input')
    damaged_input = Input(shape=img_shape, name='damaged_input')

    # Encoder part
    encoder = Sequential([
        Flatten(input_shape=img_shape),
        Dense(512),
        LeakyReLU(alpha=0.2),
        Dense(256),
        LeakyReLU(alpha=0.2),
    ])

    undamaged_encoded = encoder(undamaged_input)
    damaged_encoded = encoder(damaged_input)

    # Concatenate encoded representations
    merged = Concatenate()([undamaged_encoded, damaged_encoded])

    # Decoder part
    decoder = Sequential([
        Dense(512),
        LeakyReLU(alpha=0.2),
        Dense(1024),
        LeakyReLU(alpha=0.2),
        Dense(np.prod(img_shape), activation='tanh'),
        Reshape(img_shape),
    ])

    repaired_output = decoder(merged)

    model = Model(inputs=[undamaged_input, damaged_input], outputs=repaired_output)
    model.summary()

    return model

# %% [markdown]
# This function defines and returns a generator model, which generates images from random noise.

# %%
# Generator model
def build_generator(z_dim=100):
    model = Sequential()
    model.add(Dense(256, input_dim=z_dim))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(1024))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(np.prod(img_shape), activation='tanh'))
    model.add(Reshape(img_shape))
    model.summary()

    noise = Input(shape=(z_dim,))
    img = model(noise)

    return Model(noise, img)

# %% [markdown]
# This function defines and returns a discriminator model, which classifies images as real or fake.

# %%
# Discriminator model
def build_discriminator(img_shape):
    model = Sequential()
    model.add(Flatten(input_shape=img_shape))
    model.add(Dense(1024))  # Increased capacity
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(512))   # Increased capacity
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.summary()

    img = Input(shape=img_shape)
    validity = model(img)

    return Model(img, validity)

# %% [markdown]
# This function normalizes image pixel values to the range [-1, 1].

# %%
# Function to normalize images to the range [-1, 1]
def normalize_images(images):
    return 2 * images - 1

# %% [markdown]
# This function loads, resizes, and normalizes images from the dataset, identifying damaged regions based on pixel differences.

# %%
def load_and_resize_dataset(dataset_path, target_size=(128, 128), pixel_difference_threshold=50):
    damaged_images = []
    for filename in os.listdir(os.path.join(dataset_path, "damaged")):
        try:
            img = load_img(os.path.join(dataset_path, "damaged", filename), target_size=target_size)
            img = img_to_array(img) / 128.0
            damaged_images.append(img)
        except UnidentifiedImageError:
            print(f"Skipping non-image file: {filename}")

    undamaged_images = []
    for filename in os.listdir(os.path.join(dataset_path, "undamaged")):
        try:
            img = load_img(os.path.join(dataset_path, "undamaged", filename), target_size=target_size)
            img = img_to_array(img) / 128.0
            undamaged_images.append(img)
        except UnidentifiedImageError:
            print(f"Skipping non-image file: {filename}")

    min_samples = min(len(damaged_images), len(undamaged_images))
    damaged_images = damaged_images[:min_samples]
    undamaged_images = undamaged_images[:min_samples]

    damaged_images = np.array(damaged_images)
    undamaged_images = np.array(undamaged_images)

    # Identify damaged regions based on pixel differences
    damaged_regions = np.sum(np.abs(undamaged_images - damaged_images), axis=-1) > pixel_difference_threshold

    return damaged_images, undamaged_images, damaged_regions

# %% [markdown]
# These paths specify the locations of training and testing datasets, as well as the output directory for saving generated images.

# %%
# Set the paths and parameters
dataset_path = "D:/SagharGhaffari/Archive/dataset"
output_path = "D:/SagharGhaffari/Archive/output"
test_dataset_path = "D:/SagharGhaffari/Archive/testset"

# %% [markdown]
# This line loads and preprocesses the training dataset.

# %%
# Load and preprocess the dataset with reduced resolution
damaged_data, undamaged_data, damaged_regions = load_and_resize_dataset(dataset_path, target_size=(128, 128))

# %% [markdown]
# This loads and preprocesses the test dataset.

# %%
# Load and preprocess the test dataset
X_test_damaged_testset, X_test_undamaged_testset, damaged_regions_testset = load_and_resize_dataset(test_dataset_path, target_size=(128, 128))

# Combine the test sets for evaluation
X_test_testset = np.concatenate([X_test_damaged_testset, X_test_undamaged_testset])

# %% [markdown]
# These are labels used to indicate whether an image is real (valid) or fake.

# %%
# Adversarial ground truths
valid = np.ones((batch_size, 1))
fake = np.zeros((batch_size, 1))

# %% [markdown]
# This initializes and compiles the generator model.

# %%
# Build and compile the generator
generator = build_generator()
generator_optimizer = Adam(learning_rate=0.0002, beta_1=0.5)
generator.compile(loss='mse', optimizer=generator_optimizer)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               25856
#
#  leaky_re_lu (LeakyReLU)     (None, 256)               0
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 512)               0
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_2 (Dense)             (None, 1024)              525312
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 1024)              0
#
#  batch_normalization_2 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dense_3 (Dense)             (None, 49152)             50380800
#
#  reshape (Reshape)           (None, 128, 128, 3)       0
#
# =================================================================
# Total params: 51070720 (194.82 MB)
# Trainable params: 51067136 (194.81 MB)
# Non-trainable params: 3584 (14.00 KB)
# _________________________________________________________________

# %% [markdown]
# This initializes and compiles the discriminator model.

# %%
# Build and compile the discriminator
discriminator = build_discriminator(img_shape)
discriminator_optimizer = Adam(learning_rate=0.0002, beta_1=0.5)
discriminator.compile(loss='binary_crossentropy', optimizer=discriminator_optimizer, metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 49152)             0
#
#  dense_4 (Dense)             (None, 1024)              50332672
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 1024)              0
#
#  dense_5 (Dense)             (None, 512)               524800
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 512)               0
#
#  dense_6 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 50857985 (194.01 MB)
# Trainable params: 50857985 (194.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# This creates and compiles the combined model, where only the generator is trained.

# %%
# The generator takes noise as input and generates images
z = Input(shape=(z_dim,))
img = generator(z)

# For the combined model, only train the generator
discriminator.trainable = False

# The discriminator takes generated images as input and determines validity
validity = discriminator(img)

# Build and compile the combined model
combined = Model(z, validity)
combined.compile(loss='binary_crossentropy', optimizer=generator_optimizer)

# %% [markdown]
# This initializes and compiles the repair generator model.

# %%
# Build and compile the repair generator
repair_generator = build_repair_generator()
repair_generator_optimizer = Adam(learning_rate=0.0002, beta_1=0.5)
repair_generator.compile(loss='mse', optimizer=repair_generator_optimizer)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  undamaged_input (InputLaye  [(None, 128, 128, 3)]        0         []
#  r)
#
#  damaged_input (InputLayer)  [(None, 128, 128, 3)]        0         []
#
#  sequential_2 (Sequential)   (None, 256)                  2529766   ['undamaged_input[0][0]',
#                                                           4          'damaged_input[0][0]']
#
#  concatenate (Concatenate)   (None, 512)                  0         ['sequential_2[0][0]',
#                                                                      'sequential_2[1][0]']
#
#  sequential_3 (Sequential)   (None, 128, 128, 3)          5116876   ['concatenate[0][0]']
#                                                           8
#
# ==================================================================================================
# Total params: 76466432 (291.70 MB)
# Trainable params: 76466432 (291.70 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# This resizes the test images to the expected input shape of the repair generator.

# %%
# Resize the test images to the expected input shape of the repair generator
X_test_undamaged_testset_resized = np.array([resize(img, (128, 128, 3), mode='reflect', anti_aliasing=True) for img in X_test_undamaged_testset])
X_test_damaged_testset_resized = np.array([resize(img, (128, 128, 3), mode='reflect', anti_aliasing=True) for img in X_test_damaged_testset])

# %%
import numpy as np

def calculate_metrics(original, repaired, win_size=3):
    psnr_values = []
    ssim_values = []

    # Convert TensorFlow tensors to NumPy arrays
    original_np = original.numpy() if isinstance(original, tf.Tensor) else original
    repaired_np = repaired.numpy() if isinstance(repaired, tf.Tensor) else repaired

    for i in range(len(original_np)):
        # Explicitly convert to float32 to avoid the TypeError
        psnr = peak_signal_noise_ratio(original_np[i].astype(np.float32), repaired_np[i].astype(np.float32), data_range=1.0)
        ssim = structural_similarity(original_np[i].astype(np.float32), repaired_np[i].astype(np.float32), win_size=win_size, multichannel=True, data_range=1.0)
        psnr_values.append(psnr)
        ssim_values.append(ssim)

    return np.mean(psnr_values), np.mean(ssim_values)

# %% [markdown]
# ### Training the GAN and Repair Generator:
#
#
# This loop trains the GAN and repair generator for the specified number of epochs, periodically saving generated images and model weights.

# %%
# Training the GAN and repair generator
for epoch in range(epochs):
    # Sample noise and generate a batch of new images
    noise = np.random.normal(0, 1, (batch_size, z_dim))
    gen_imgs = generator(noise, training=False)  # Set training to False

    # Create labels for training the discriminator
    valid_labels = np.ones((batch_size, 1))
    fake_labels = np.zeros((batch_size, 1))

    # Randomly select a batch of undamaged and damaged images from the train set
    idx = np.random.randint(0, undamaged_data.shape[0], batch_size // 2)
    X_batch_undamaged = undamaged_data[idx]
    X_batch_damaged = damaged_data[idx]

    # Concatenate undamaged and damaged batches for training the discriminator
    X_batch = np.concatenate([X_batch_undamaged, X_batch_damaged])

    # Train the discriminator
    d_loss_real = discriminator.train_on_batch(X_batch_undamaged, valid_labels[:batch_size // 2])
    d_loss_fake = discriminator.train_on_batch(gen_imgs, fake_labels)
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

    # Train the generator
    g_loss = combined.train_on_batch(noise, valid_labels)

    # Print progress
    print(f"{epoch}/{epochs} [D loss: {d_loss[0]} | D accuracy: {100 * d_loss[1]}] [G loss: {g_loss}]")

    # Sample noise and generate a batch of repaired images
    # Rescale images to 0-1
    X_test_undamaged_rescaled = 0.5 * (X_test_undamaged_testset_resized + 1)
    X_test_damaged_rescaled = 0.5 * (X_test_damaged_testset_resized + 1)

    repair_noise = np.random.normal(0, 1, (batch_size, z_dim))
    repaired_imgs = repair_generator([X_test_undamaged_testset_resized, X_test_damaged_testset_resized], training=False)
    repaired_imgs_rescaled = 0.5 * (repaired_imgs + 1)

    # Train the repair generator
    repair_loss = repair_generator.train_on_batch([X_test_undamaged_testset_resized, X_test_damaged_testset_resized], X_test_undamaged_testset_resized)

    # Print repair progress
    print(f"[Repair Epoch {epoch}/{epochs}] [Repair loss: {repair_loss}]")

    # Calculate and print metrics
    psnr_value, ssim_value = calculate_metrics(X_test_undamaged_rescaled, repaired_imgs_rescaled, win_size=3)
    print(f"[Quantitative Evaluation] [PSNR: {psnr_value}, SSIM: {ssim_value}]")

    # Save generated images and update TensorBoard logs at specified intervals
    if epoch % save_interval == 0:
        save_generated_images(epoch, repair_generator, output_path, X_test_undamaged_testset, X_test_damaged_testset)

        # Save generator weights
        generator.save_weights(f"generator_weights_epoch_{epoch}.h5")

        # Save discriminator weights
        discriminator.save_weights(f"discriminator_weights_epoch_{epoch}.h5")

        # Save repair generator weights
        repair_generator.save_weights(f"repair_generator_weights_epoch_{epoch}.h5")
# Out:
# 0/1000 [D loss: 0.5870512574911118 | D accuracy: 60.9375] [G loss: 0.686246931552887]
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_train_function.<locals>.train_function at 0x000001D79001AA20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.models import Model as KerasModel
from tensorflow.keras.preprocessing import image
from scipy.linalg import sqrtm
from skimage.transform import resize
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, LeakyReLU, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# calculate_metrics is a function that takes two sets of images (original and repaired) and an optional parameter win_size.
#
# It initializes empty lists to store PSNR and SSIM values for each image pair.
#
# It then iterates through the images, calculates PSNR and SSIM using the specified window size (win_size), and appends the values to the respective lists.
#
# Finally, it returns the mean PSNR and mean SSIM values across all images.

# %%
def calculate_metrics(original, repaired, win_size=5):
    psnr_values = []
    ssim_values = []

    for i in range(len(original)):
        psnr = peak_signal_noise_ratio(original[i], repaired[i], data_range=1.0)
        ssim = structural_similarity(original[i], repaired[i], win_size=win_size, multichannel=True, data_range=1.0)
        psnr_values.append(psnr)
        ssim_values.append(ssim)

    return np.mean(psnr_values), np.mean(ssim_values)

# %% [markdown]
# This code implements a diffusion model for repairing damaged images. The diffusion model is a generative model that simulates the process of diffusing noise into a damaged image to generate a repaired version.

# %% [markdown]
# Import necessary libraries and set parameters, including image dimensions, noise vector size, and training parameters.

# %% [markdown]
# img_rows, img_cols, channels: Dimensions of the images (128x128 pixels with 3 color channels).
#
# z_dim: Size of the noise vector (100).
#
# epochs: Number of training epochs (5000).
#
# batch_size: Number of samples in each batch (64).
#
# save_interval: Interval for saving generated images (every 100 epochs).
#
# Learning rate and beta1 for the Adam optimizer in the repair model: learning_rate=0.0002, beta_1=0.5.

# %%
# Set the seed for reproducibility
np.random.seed(1000)

# Define image parameters
img_rows, img_cols, channels = 128, 128, 3
img_shape = (img_rows, img_cols, channels)
z_dim = 100  # Size of the noise vector
epochs = 1000
batch_size = 64
save_interval = 100  # Set the interval to save generated images

# %% [markdown]
# save_generated_images:
#
# Visualizes and saves a comparison of undamaged, damaged, and repaired images.
#
# Parameters:
#
# epoch: Current training epoch.
#
# repair_model: The diffusion model.
#
# output_path: Path to save the generated images.
#
# X_test_undamaged, X_test_damaged: Test sets for visualization.
#
# r, c: Number of rows and columns in the visualization grid.

# %%
# Function to save generated images
def save_generated_images(epoch, repair_model, output_path, X_test_undamaged, X_test_damaged, r=5, c=3):
    # Resize images to match the repair model input shape
    X_test_undamaged_resized = np.array([resize(img, (128, 128, 3), mode='reflect', anti_aliasing=True) for img in X_test_undamaged])
    X_test_damaged_resized = np.array([resize(img, (128, 128, 3), mode='reflect', anti_aliasing=True) for img in X_test_damaged])

    # Generate repaired images for damaged parts
    repaired_imgs = repair_model.predict([X_test_undamaged_resized, X_test_damaged_resized])

    # Rescale images to 0-1
    X_test_undamaged_rescaled = 0.5 * (X_test_undamaged_resized + 1)
    X_test_damaged_rescaled = 0.5 * (X_test_damaged_resized + 1)
    repaired_imgs_rescaled = 0.5 * (repaired_imgs + 1)

    fig, axs = plt.subplots(r, c, figsize=(15, 15))
    cnt = 0
    for i in range(r):
        axs[i, 0].imshow(X_test_undamaged_rescaled[cnt])
        axs[i, 0].axis('off')
        axs[i, 0].set_title("Real (Undamaged)")

        axs[i, 1].imshow(X_test_damaged_rescaled[cnt])
        axs[i, 1].axis('off')
        axs[i, 1].set_title("Damaged")

        axs[i, 2].imshow(repaired_imgs_rescaled[cnt])
        axs[i, 2].axis('off')
        axs[i, 2].set_title("Repaired")

        cnt += 1

    fig.savefig(output_path + f"/repaired_image_epoch_{epoch}.png")
    plt.close()

# %% [markdown]
# Builds the diffusion model using TensorFlow Probability.
#
# Input: Undamaged and damaged images.
#
# Output: Repaired output based on the diffusion process.
#
# Uses a simple Gaussian diffusion process.

# %% [markdown]
# diffusion_function:
#
# Defines the diffusion process using TensorFlow Probability.
#
# Parameters:
#
# inputs: Tuple of undamaged and damaged images.
#
# Returns the output after simulating the diffusion process.

# %% [markdown]
# normalize_images:
#
# Normalizes images to the range [-1, 1].

# %%
# Function to normalize images to the range [-1, 1]
def normalize_images(images):
    return 2 * images - 1

# %% [markdown]
# load_and_resize_dataset:
#
# Loads and resizes the dataset of damaged and undamaged images.
#
# Parameters:
#
# dataset_path: Path to the dataset.
#
# target_size: Target size for resizing.
#
# Returns the normalized damaged and undamaged images.

# %%
def load_and_resize_dataset(dataset_path, target_size=(128, 128), pixel_difference_threshold=50):
    damaged_images = []
    for filename in os.listdir(os.path.join(dataset_path, "damaged")):
        try:
            img = load_img(os.path.join(dataset_path, "damaged", filename), target_size=target_size)
            img = img_to_array(img) / 128.0
            damaged_images.append(img)
        except UnidentifiedImageError:
            print(f"Skipping non-image file: {filename}")

    undamaged_images = []
    for filename in os.listdir(os.path.join(dataset_path, "undamaged")):
        try:
            img = load_img(os.path.join(dataset_path, "undamaged", filename), target_size=target_size)
            img = img_to_array(img) / 128.0
            undamaged_images.append(img)
        except UnidentifiedImageError:
            print(f"Skipping non-image file: {filename}")

    damaged_images = normalize_images(np.array(damaged_images))
    undamaged_images = normalize_images(np.array(undamaged_images))

    return damaged_images, undamaged_images

# %% [markdown]
# Initialization:
#
#           Sets the random seed for reproducibility.
#
#           Defines image parameters, hyperparameters, and paths.
#
# Load and Preprocess Dataset:
#
#           Loads and resizes the training and test datasets.
#
# Build and Compile Repair Model:
#
#           Builds the diffusion repair model.
#           Compiles the model with Mean Squared Error (MSE) loss and the Adam optimizer.

# %%
# Set the paths and parameters

dataset_path = r"D:\SagharGhaffari\Archive\dataset"
output_path = r"D:\SagharGhaffari\Archive\diffusionoutput"
test_dataset_path = r"D:\SagharGhaffari\Archive\testset"


# Load and preprocess the dataset with reduced resolution
damaged_data, undamaged_data = load_and_resize_dataset(dataset_path, target_size=(128, 128))


# Load and preprocess the test dataset
X_test_damaged_testset, X_test_undamaged_testset = load_and_resize_dataset(test_dataset_path, target_size=(128, 128))

# Adversarial ground truths
valid = np.ones((batch_size, 1))
fake = np.zeros((batch_size, 1))



# Resize the test images to the expected input shape of the repair model
undamaged_resized = np.array([resize(img, (128, 128, 3), mode='reflect', anti_aliasing=True) for img in undamaged_data])
damaged_resized = np.array([resize(img, (128, 128, 3), mode='reflect', anti_aliasing=True) for img in damaged_data])
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  damaged_input (InputLayer)  [(None, 128, 128, 3)]        0         []
#
#  tf.compat.v1.shape (TFOpLa  (4,)                         0         ['damaged_input[0][0]']
#  mbda)
#
#  tf.cast (TFOpLambda)        (4,)                         0         ['tf.compat.v1.shape[0][0]']
#
#  tf.convert_to_tensor (TFOp  (4,)                         0         ['tf.cast[0][0]']
#  Lambda)
#
#  tf.math.reduce_prod (TFOpL  ()                           0         ['tf.convert_to_tensor[0][0]']
#  ambda)
#
#  tf.concat (TFOpLambda)      (1,)                         0         ['tf.math.reduce_prod[0][0]']
#
#  tf.random.normal (TFOpLamb  (None,)                      0         ['tf.concat[0][0]']
#  da)
#
#  tf.math.multiply (TFOpLamb  (None,)                      0         ['tf.random.normal[0][0]']
#  da)
#
#  tf.__operators__.add (TFOp  (None,)                      0         ['tf.math.multiply[0][0]']
#  Lambda)
#
#  tf.convert_to_tensor_2 (TF  (None,)                      0         ['tf.__operators__.add[0][0]']
#  OpLambda)
#
#  tf.compat.v1.shape_1 (TFOp  (1,)                         0         ['tf.convert_to_tensor_2[0][0]
#  Lambda)                                                            ']
#
#  tf.convert_to_tensor_1 (TF  (4,)                         0         ['tf.convert_to_tensor[0][0]']
#  OpLambda)
#
#  tf.__operators__.getitem (  (0,)                         0         ['tf.compat.v1.shape_1[0][0]']
#  SlicingOpLambda)
#
#  tf.concat_1 (TFOpLambda)    (4,)                         0         ['tf.convert_to_tensor_1[0][0]
#                                                                     ',
#                                                                      'tf.__operators__.getitem[0][
#                                                                     0]']
#
#  tf.reshape (TFOpLambda)     (None, 128, 128, 3)          0         ['tf.__operators__.add[0][0]',
#                                                                      'tf.concat_1[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 128, 128, 3)          0         ['damaged_input[0][0]',
#  OpLambda)                                                           'tf.reshape[0][0]']
#
#  tf.compat.v1.shape_2 (TFOp  (4,)                         0         ['tf.__operators__.add_1[0][0]
#  Lambda)                                                            ']
#
#  tf.cast_1 (TFOpLambda)      (4,)                         0         ['tf.compat.v1.shape_2[0][0]']
#
#  tf.convert_to_tensor_3 (TF  (4,)                         0         ['tf.cast_1[0][0]']
#  OpLambda)
#
#  tf.math.reduce_prod_1 (TFO  ()                           0         ['tf.convert_to_tensor_3[0][0]
#  pLambda)                                                           ']
#
#  tf.concat_2 (TFOpLambda)    (1,)                         0         ['tf.math.reduce_prod_1[0][0]'
#                                                                     ]
#
#  tf.random.normal_1 (TFOpLa  (None,)                      0         ['tf.concat_2[0][0]']
#  mbda)
#
#  tf.math.multiply_1 (TFOpLa  (None,)                      0         ['tf.random.normal_1[0][0]']
#  mbda)
#
#  tf.__operators__.add_2 (TF  (None,)                      0         ['tf.math.multiply_1[0][0]']
#  OpLambda)
#
#  tf.convert_to_tensor_5 (TF  (None,)                      0         ['tf.__operators__.add_2[0][0]
#  OpLambda)                                                          ']
#
#  tf.compat.v1.shape_3 (TFOp  (1,)                         0         ['tf.convert_to_tensor_5[0][0]
#  Lambda)                                                            ']
#
#  tf.convert_to_tensor_4 (TF  (4,)                         0         ['tf.convert_to_tensor_3[0][0]
#  OpLambda)                                                          ']
#
#  tf.__operators__.getitem_1  (0,)                         0         ['tf.compat.v1.shape_3[0][0]']
#   (SlicingOpLambda)
#
#  tf.concat_3 (TFOpLambda)    (4,)                         0         ['tf.convert_to_tensor_4[0][0]
#                                                                     ',
#                                                                      'tf.__operators__.getitem_1[0
#                                                                     ][0]']
#
#  tf.reshape_1 (TFOpLambda)   (None, 128, 128, 3)          0         ['tf.__operators__.add_2[0][0]
#                                                                     ',
#                                                                      'tf.concat_3[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 128, 128, 3)          0         ['tf.__operators__.add_1[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.reshape_1[0][0]']
#
#  tf.compat.v1.shape_4 (TFOp  (4,)                         0         ['tf.__operators__.add_3[0][0]
#  Lambda)                                                            ']
#
#  tf.cast_2 (TFOpLambda)      (4,)                         0         ['tf.compat.v1.shape_4[0][0]']
#
#  tf.convert_to_tensor_6 (TF  (4,)                         0         ['tf.cast_2[0][0]']
#  OpLambda)
#
#  tf.math.reduce_prod_2 (TFO  ()                           0         ['tf.convert_to_tensor_6[0][0]
#  pLambda)                                                           ']
#
#  tf.concat_4 (TFOpLambda)    (1,)                         0         ['tf.math.reduce_prod_2[0][0]'
#                                                                     ]
#
#  tf.random.normal_2 (TFOpLa  (None,)                      0         ['tf.concat_4[0][0]']
#  mbda)
#
#  tf.math.multiply_2 (TFOpLa  (None,)                      0         ['tf.random.normal_2[0][0]']
#  mbda)
#
#  tf.__operators__.add_4 (TF  (None,)                      0         ['tf.math.multiply_2[0][0]']
#  OpLambda)
#
#  tf.convert_to_tensor_8 (TF  (None,)                      0         ['tf.__operators__.add_4[0][0]
#  OpLambda)                                                          ']
#
#  tf.compat.v1.shape_5 (TFOp  (1,)                         0         ['tf.convert_to_tensor_8[0][0]
#  Lambda)                                                            ']
#
#  tf.convert_to_tensor_7 (TF  (4,)                         0         ['tf.convert_to_tensor_6[0][0]
#  OpLambda)                                                          ']
#
#  tf.__operators__.getitem_2  (0,)                         0         ['tf.compat.v1.shape_5[0][0]']
#   (SlicingOpLambda)
#
#  tf.concat_5 (TFOpLambda)    (4,)                         0         ['tf.convert_to_tensor_7[0][0]
#                                                                     ',
#                                                                      'tf.__operators__.getitem_2[0
#                                                                     ][0]']
#
#  tf.reshape_2 (TFOpLambda)   (None, 128, 128, 3)          0         ['tf.__operators__.add_4[0][0]
#                                                                     ',
#                                                                      'tf.concat_5[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 128, 128, 3)          0         ['tf.__operators__.add_3[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.reshape_2[0][0]']
#
#  tf.compat.v1.shape_6 (TFOp  (4,)                         0         ['tf.__operators__.add_5[0][0]
#  Lambda)                                                            ']
#
#  tf.cast_3 (TFOpLambda)      (4,)                         0         ['tf.compat.v1.shape_6[0][0]']
#
#  tf.convert_to_tensor_9 (TF  (4,)                         0         ['tf.cast_3[0][0]']
#  OpLambda)
#
#  tf.math.reduce_prod_3 (TFO  ()                           0         ['tf.convert_to_tensor_9[0][0]
#  pLambda)                                                           ']
#
#  tf.concat_6 (TFOpLambda)    (1,)                         0         ['tf.math.reduce_prod_3[0][0]'
#                                                                     ]
#
#  tf.random.normal_3 (TFOpLa  (None,)                      0         ['tf.concat_6[0][0]']
#  mbda)
#
#  tf.math.multiply_3 (TFOpLa  (None,)                      0         ['tf.random.normal_3[0][0]']
#  mbda)
#
#  tf.__operators__.add_6 (TF  (None,)                      0         ['tf.math.multiply_3[0][0]']
#  OpLambda)
#
#  tf.convert_to_tensor_11 (T  (None,)                      0         ['tf.__operators__.add_6[0][0]
#  FOpLambda)                                                         ']
#
#  tf.compat.v1.shape_7 (TFOp  (1,)                         0         ['tf.convert_to_tensor_11[0][0
#  Lambda)                                                            ]']
#
#  tf.convert_to_tensor_10 (T  (4,)                         0         ['tf.convert_to_tensor_9[0][0]
#  FOpLambda)                                                         ']
#
#  tf.__operators__.getitem_3  (0,)                         0         ['tf.compat.v1.shape_7[0][0]']
#   (SlicingOpLambda)
#
#  tf.concat_7 (TFOpLambda)    (4,)                         0         ['tf.convert_to_tensor_10[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.getitem_3[0
#                                                                     ][0]']
#
#  tf.reshape_3 (TFOpLambda)   (None, 128, 128, 3)          0         ['tf.__operators__.add_6[0][0]
#                                                                     ',
#                                                                      'tf.concat_7[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 128, 128, 3)          0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.reshape_3[0][0]']
#
#  tf.compat.v1.shape_8 (TFOp  (4,)                         0         ['tf.__operators__.add_7[0][0]
#  Lambda)                                                            ']
#
#  tf.cast_4 (TFOpLambda)      (4,)                         0         ['tf.compat.v1.shape_8[0][0]']
#
#  tf.convert_to_tensor_12 (T  (4,)                         0         ['tf.cast_4[0][0]']
#  FOpLambda)
#
#  tf.math.reduce_prod_4 (TFO  ()                           0         ['tf.convert_to_tensor_12[0][0
#  pLambda)                                                           ]']
#
#  tf.concat_8 (TFOpLambda)    (1,)                         0         ['tf.math.reduce_prod_4[0][0]'
#                                                                     ]
#
#  tf.random.normal_4 (TFOpLa  (None,)                      0         ['tf.concat_8[0][0]']
#  mbda)
#
#  tf.math.multiply_4 (TFOpLa  (None,)                      0         ['tf.random.normal_4[0][0]']
#  mbda)
#
#  tf.__operators__.add_8 (TF  (None,)                      0         ['tf.math.multiply_4[0][0]']
#  OpLambda)
#
#  tf.convert_to_tensor_14 (T  (None,)                      0         ['tf.__operators__.add_8[0][0]
#  FOpLambda)                                                         ']
#
#  tf.compat.v1.shape_9 (TFOp  (1,)                         0         ['tf.convert_to_tensor_14[0][0
#  Lambda)                                                            ]']
#
#  tf.convert_to_tensor_13 (T  (4,)                         0         ['tf.convert_to_tensor_12[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.getitem_4  (0,)                         0         ['tf.compat.v1.shape_9[0][0]']
#   (SlicingOpLambda)
#
#  tf.concat_9 (TFOpLambda)    (4,)                         0         ['tf.convert_to_tensor_13[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.getitem_4[0
#                                                                     ][0]']
#
#  tf.reshape_4 (TFOpLambda)   (None, 128, 128, 3)          0         ['tf.__operators__.add_8[0][0]
#                                                                     ',
#                                                                      'tf.concat_9[0][0]']
#
#  tf.__operators__.add_9 (TF  (None, 128, 128, 3)          0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.reshape_4[0][0]']
#
#  tf.compat.v1.shape_10 (TFO  (4,)                         0         ['tf.__operators__.add_9[0][0]
#  pLambda)                                                           ']
#
#  tf.cast_5 (TFOpLambda)      (4,)                         0         ['tf.compat.v1.shape_10[0][0]'
#                                                                     ]
#
#  tf.convert_to_tensor_15 (T  (4,)                         0         ['tf.cast_5[0][0]']
#  FOpLambda)
#
#  tf.math.reduce_prod_5 (TFO  ()                           0         ['tf.convert_to_tensor_15[0][0
#  pLambda)                                                           ]']
#
#  tf.concat_10 (TFOpLambda)   (1,)                         0         ['tf.math.reduce_prod_5[0][0]'
#                                                                     ]
#
#  tf.random.normal_5 (TFOpLa  (None,)                      0         ['tf.concat_10[0][0]']
#  mbda)
#
#  tf.math.multiply_5 (TFOpLa  (None,)                      0         ['tf.random.normal_5[0][0]']
#  mbda)
#
#  tf.__operators__.add_10 (T  (None,)                      0         ['tf.math.multiply_5[0][0]']
#  FOpLambda)
#
#  tf.convert_to_tensor_17 (T  (None,)                      0         ['tf.__operators__.add_10[0][0
#  FOpLambda)                                                         ]']
#
#  tf.compat.v1.shape_11 (TFO  (1,)                         0         ['tf.convert_to_tensor_17[0][0
#  pLambda)                                                           ]']
#
#  tf.convert_to_tensor_16 (T  (4,)                         0         ['tf.convert_to_tensor_15[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.getitem_5  (0,)                         0         ['tf.compat.v1.shape_11[0][0]'
#   (SlicingOpLambda)                                                 ]
#
#  tf.concat_11 (TFOpLambda)   (4,)                         0         ['tf.convert_to_tensor_16[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.getitem_5[0
#                                                                     ][0]']
#
#  tf.reshape_5 (TFOpLambda)   (None, 128, 128, 3)          0         ['tf.__operators__.add_10[0][0
#                                                                     ]',
#                                                                      'tf.concat_11[0][0]']
#
#  tf.__operators__.add_11 (T  (None, 128, 128, 3)          0         ['tf.__operators__.add_9[0][0]
#  FOpLambda)                                                         ',
#                                                                      'tf.reshape_5[0][0]']
#
#  tf.compat.v1.shape_12 (TFO  (4,)                         0         ['tf.__operators__.add_11[0][0
#  pLambda)                                                           ]']
#
#  tf.cast_6 (TFOpLambda)      (4,)                         0         ['tf.compat.v1.shape_12[0][0]'
#                                                                     ]
#
#  tf.convert_to_tensor_18 (T  (4,)                         0         ['tf.cast_6[0][0]']
#  FOpLambda)
#
#  tf.math.reduce_prod_6 (TFO  ()                           0         ['tf.convert_to_tensor_18[0][0
#  pLambda)                                                           ]']
#
#  tf.concat_12 (TFOpLambda)   (1,)                         0         ['tf.math.reduce_prod_6[0][0]'
#                                                                     ]
#
#  tf.random.normal_6 (TFOpLa  (None,)                      0         ['tf.concat_12[0][0]']
#  mbda)
#
#  tf.math.multiply_6 (TFOpLa  (None,)                      0         ['tf.random.normal_6[0][0]']
#  mbda)
#
#  tf.__operators__.add_12 (T  (None,)                      0         ['tf.math.multiply_6[0][0]']
#  FOpLambda)
#
#  tf.convert_to_tensor_20 (T  (None,)                      0         ['tf.__operators__.add_12[0][0
#  FOpLambda)                                                         ]']
#
#  tf.compat.v1.shape_13 (TFO  (1,)                         0         ['tf.convert_to_tensor_20[0][0
#  pLambda)                                                           ]']
#
#  tf.convert_to_tensor_19 (T  (4,)                         0         ['tf.convert_to_tensor_18[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.getitem_6  (0,)                         0         ['tf.compat.v1.shape_13[0][0]'
#   (SlicingOpLambda)                                                 ]
#
#  tf.concat_13 (TFOpLambda)   (4,)                         0         ['tf.convert_to_tensor_19[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.getitem_6[0
#                                                                     ][0]']
#
#  tf.reshape_6 (TFOpLambda)   (None, 128, 128, 3)          0         ['tf.__operators__.add_12[0][0
#                                                                     ]',
#                                                                      'tf.concat_13[0][0]']
#
#  tf.__operators__.add_13 (T  (None, 128, 128, 3)          0         ['tf.__operators__.add_11[0][0
#  FOpLambda)                                                         ]',
#                                                                      'tf.reshape_6[0][0]']
#
#  tf.compat.v1.shape_14 (TFO  (4,)                         0         ['tf.__operators__.add_13[0][0
#  pLambda)                                                           ]']
#
#  tf.cast_7 (TFOpLambda)      (4,)                         0         ['tf.compat.v1.shape_14[0][0]'
#                                                                     ]
#
#  tf.convert_to_tensor_21 (T  (4,)                         0         ['tf.cast_7[0][0]']
#  FOpLambda)
#
#  tf.math.reduce_prod_7 (TFO  ()                           0         ['tf.convert_to_tensor_21[0][0
#  pLambda)                                                           ]']
#
#  tf.concat_14 (TFOpLambda)   (1,)                         0         ['tf.math.reduce_prod_7[0][0]'
#                                                                     ]
#
#  tf.random.normal_7 (TFOpLa  (None,)                      0         ['tf.concat_14[0][0]']
#  mbda)
#
#  tf.math.multiply_7 (TFOpLa  (None,)                      0         ['tf.random.normal_7[0][0]']
#  mbda)
#
#  tf.__operators__.add_14 (T  (None,)                      0         ['tf.math.multiply_7[0][0]']
#  FOpLambda)
#
#  tf.convert_to_tensor_23 (T  (None,)                      0         ['tf.__operators__.add_14[0][0
#  FOpLambda)                                                         ]']
#
#  tf.compat.v1.shape_15 (TFO  (1,)                         0         ['tf.convert_to_tensor_23[0][0
#  pLambda)                                                           ]']
#
#  tf.convert_to_tensor_22 (T  (4,)                         0         ['tf.convert_to_tensor_21[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.getitem_7  (0,)                         0         ['tf.compat.v1.shape_15[0][0]'
#   (SlicingOpLambda)                                                 ]
#
#  tf.concat_15 (TFOpLambda)   (4,)                         0         ['tf.convert_to_tensor_22[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.getitem_7[0
#                                                                     ][0]']
#
#  tf.reshape_7 (TFOpLambda)   (None, 128, 128, 3)          0         ['tf.__operators__.add_14[0][0
#                                                                     ]',
#                                                                      'tf.concat_15[0][0]']
#
#  tf.__operators__.add_15 (T  (None, 128, 128, 3)          0         ['tf.__operators__.add_13[0][0
#  FOpLambda)                                                         ]',
#                                                                      'tf.reshape_7[0][0]']
#
#  tf.compat.v1.shape_16 (TFO  (4,)                         0         ['tf.__operators__.add_15[0][0
#  pLambda)                                                           ]']
#
#  tf.cast_8 (TFOpLambda)      (4,)                         0         ['tf.compat.v1.shape_16[0][0]'
#                                                                     ]
#
#  tf.convert_to_tensor_24 (T  (4,)                         0         ['tf.cast_8[0][0]']
#  FOpLambda)
#
#  tf.math.reduce_prod_8 (TFO  ()                           0         ['tf.convert_to_tensor_24[0][0
#  pLambda)                                                           ]']
#
#  tf.concat_16 (TFOpLambda)   (1,)                         0         ['tf.math.reduce_prod_8[0][0]'
#                                                                     ]
#
#  tf.random.normal_8 (TFOpLa  (None,)                      0         ['tf.concat_16[0][0]']
#  mbda)
#
#  tf.math.multiply_8 (TFOpLa  (None,)                      0         ['tf.random.normal_8[0][0]']
#  mbda)
#
#  tf.__operators__.add_16 (T  (None,)                      0         ['tf.math.multiply_8[0][0]']
#  FOpLambda)
#
#  tf.convert_to_tensor_26 (T  (None,)                      0         ['tf.__operators__.add_16[0][0
#  FOpLambda)                                                         ]']
#
#  tf.compat.v1.shape_17 (TFO  (1,)                         0         ['tf.convert_to_tensor_26[0][0
#  pLambda)                                                           ]']
#
#  tf.convert_to_tensor_25 (T  (4,)                         0         ['tf.convert_to_tensor_24[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.getitem_8  (0,)                         0         ['tf.compat.v1.shape_17[0][0]'
#   (SlicingOpLambda)                                                 ]
#
#  tf.concat_17 (TFOpLambda)   (4,)                         0         ['tf.convert_to_tensor_25[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.getitem_8[0
#                                                                     ][0]']
#
#  tf.reshape_8 (TFOpLambda)   (None, 128, 128, 3)          0         ['tf.__operators__.add_16[0][0
#                                                                     ]',
#                                                                      'tf.concat_17[0][0]']
#
#  tf.__operators__.add_17 (T  (None, 128, 128, 3)          0         ['tf.__operators__.add_15[0][0
#  FOpLambda)                                                         ]',
#                                                                      'tf.reshape_8[0][0]']
#
#  tf.compat.v1.shape_18 (TFO  (4,)                         0         ['tf.__operators__.add_17[0][0
#  pLambda)                                                           ]']
#
#  tf.cast_9 (TFOpLambda)      (4,)                         0         ['tf.compat.v1.shape_18[0][0]'
#                                                                     ]
#
#  tf.convert_to_tensor_27 (T  (4,)                         0         ['tf.cast_9[0][0]']
#  FOpLambda)
#
#  tf.math.reduce_prod_9 (TFO  ()                           0         ['tf.convert_to_tensor_27[0][0
#  pLambda)                                                           ]']
#
#  tf.concat_18 (TFOpLambda)   (1,)                         0         ['tf.math.reduce_prod_9[0][0]'
#                                                                     ]
#
#  tf.random.normal_9 (TFOpLa  (None,)                      0         ['tf.concat_18[0][0]']
#  mbda)
#
#  tf.math.multiply_9 (TFOpLa  (None,)                      0         ['tf.random.normal_9[0][0]']
#  mbda)
#
#  tf.__operators__.add_18 (T  (None,)                      0         ['tf.math.multiply_9[0][0]']
#  FOpLambda)
#
#  tf.convert_to_tensor_29 (T  (None,)                      0         ['tf.__operators__.add_18[0][0
#  FOpLambda)                                                         ]']
#
#  tf.compat.v1.shape_19 (TFO  (1,)                         0         ['tf.convert_to_tensor_29[0][0
#  pLambda)                                                           ]']
#
#  tf.convert_to_tensor_28 (T  (4,)                         0         ['tf.convert_to_tensor_27[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.getitem_9  (0,)                         0         ['tf.compat.v1.shape_19[0][0]'
#   (SlicingOpLambda)                                                 ]
#
#  tf.concat_19 (TFOpLambda)   (4,)                         0         ['tf.convert_to_tensor_28[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.getitem_9[0
#                                                                     ][0]']
#
#  tf.reshape_9 (TFOpLambda)   (None, 128, 128, 3)          0         ['tf.__operators__.add_18[0][0
#                                                                     ]',
#                                                                      'tf.concat_19[0][0]']
#
#  tf.__operators__.add_19 (T  (None, 128, 128, 3)          0         ['tf.__operators__.add_17[0][0
# ...
#  tf.__operators__.add_33 (T  (None, 128, 128, 3)          0         ['tf.__operators__.add_31[0][0
#  FOpLambda)                                                         ]',
#                                                                      'tf.reshape_16[0][0]']
#
#  tf.compat.v1.shape_34 (TFO  (4,)                         0         ['tf.__operators__.add_33[0][0
#  pLambda)                                                           ]']
#
#  tf.cast_17 (TFOpLambda)     (4,)                         0         ['tf.compat.v1.shape_34[0][0]'
#                                                                     ]
#
#  tf.convert_to_tensor_51 (T  (4,)                         0         ['tf.cast_17[0][0]']
#  FOpLambda)
#
#  tf.math.reduce_prod_17 (TF  ()                           0         ['tf.convert_to_tensor_51[0][0
#  OpLambda)                                                          ]']
#
#  tf.concat_34 (TFOpLambda)   (1,)                         0         ['tf.math.reduce_prod_17[0][0]
#                                                                     ']
#
#  tf.random.normal_17 (TFOpL  (None,)                      0         ['tf.concat_34[0][0]']
#  ambda)
#
#  tf.math.multiply_17 (TFOpL  (None,)                      0         ['tf.random.normal_17[0][0]']
#  ambda)
#
#  tf.__operators__.add_34 (T  (None,)                      0         ['tf.math.multiply_17[0][0]']
#  FOpLambda)
#
#  tf.convert_to_tensor_53 (T  (None,)                      0         ['tf.__operators__.add_34[0][0
#  FOpLambda)                                                         ]']
#
#  tf.compat.v1.shape_35 (TFO  (1,)                         0         ['tf.convert_to_tensor_53[0][0
#  pLambda)                                                           ]']
#
#  tf.convert_to_tensor_52 (T  (4,)                         0         ['tf.convert_to_tensor_51[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.getitem_1  (0,)                         0         ['tf.compat.v1.shape_35[0][0]'
#  7 (SlicingOpLambda)                                                ]
#
#  tf.concat_35 (TFOpLambda)   (4,)                         0         ['tf.convert_to_tensor_52[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.getitem_17[
#                                                                     0][0]']
#
#  tf.reshape_17 (TFOpLambda)  (None, 128, 128, 3)          0         ['tf.__operators__.add_34[0][0
#                                                                     ]',
#                                                                      'tf.concat_35[0][0]']
#
#  tf.__operators__.add_35 (T  (None, 128, 128, 3)          0         ['tf.__operators__.add_33[0][0
#  FOpLambda)                                                         ]',
#                                                                      'tf.reshape_17[0][0]']
#
#  tf.compat.v1.shape_36 (TFO  (4,)                         0         ['tf.__operators__.add_35[0][0
#  pLambda)                                                           ]']
#
#  tf.cast_18 (TFOpLambda)     (4,)                         0         ['tf.compat.v1.shape_36[0][0]'
#                                                                     ]
#
#  tf.convert_to_tensor_54 (T  (4,)                         0         ['tf.cast_18[0][0]']
#  FOpLambda)
#
#  tf.math.reduce_prod_18 (TF  ()                           0         ['tf.convert_to_tensor_54[0][0
#  OpLambda)                                                          ]']
#
#  tf.concat_36 (TFOpLambda)   (1,)                         0         ['tf.math.reduce_prod_18[0][0]
#                                                                     ']
#
#  tf.random.normal_18 (TFOpL  (None,)                      0         ['tf.concat_36[0][0]']
#  ambda)
#
#  tf.math.multiply_18 (TFOpL  (None,)                      0         ['tf.random.normal_18[0][0]']
#  ambda)
#
#  tf.__operators__.add_36 (T  (None,)                      0         ['tf.math.multiply_18[0][0]']
#  FOpLambda)
#
#  tf.convert_to_tensor_56 (T  (None,)                      0         ['tf.__operators__.add_36[0][0
#  FOpLambda)                                                         ]']
#
#  tf.compat.v1.shape_37 (TFO  (1,)                         0         ['tf.convert_to_tensor_56[0][0
#  pLambda)                                                           ]']
#
#  tf.convert_to_tensor_55 (T  (4,)                         0         ['tf.convert_to_tensor_54[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.getitem_1  (0,)                         0         ['tf.compat.v1.shape_37[0][0]'
#  8 (SlicingOpLambda)                                                ]
#
#  tf.concat_37 (TFOpLambda)   (4,)                         0         ['tf.convert_to_tensor_55[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.getitem_18[
#                                                                     0][0]']
#
#  tf.reshape_18 (TFOpLambda)  (None, 128, 128, 3)          0         ['tf.__operators__.add_36[0][0
#                                                                     ]',
#                                                                      'tf.concat_37[0][0]']
#
#  tf.__operators__.add_37 (T  (None, 128, 128, 3)          0         ['tf.__operators__.add_35[0][0
#  FOpLambda)                                                         ]',
#                                                                      'tf.reshape_18[0][0]']
#
#  tf.compat.v1.shape_38 (TFO  (4,)                         0         ['tf.__operators__.add_37[0][0
#  pLambda)                                                           ]']
#
#  tf.cast_19 (TFOpLambda)     (4,)                         0         ['tf.compat.v1.shape_38[0][0]'
#                                                                     ]
#
#  tf.convert_to_tensor_57 (T  (4,)                         0         ['tf.cast_19[0][0]']
#  FOpLambda)
#
#  tf.math.reduce_prod_19 (TF  ()                           0         ['tf.convert_to_tensor_57[0][0
#  OpLambda)                                                          ]']
#
#  tf.concat_38 (TFOpLambda)   (1,)                         0         ['tf.math.reduce_prod_19[0][0]
#                                                                     ']
#
#  tf.random.normal_19 (TFOpL  (None,)                      0         ['tf.concat_38[0][0]']
#  ambda)
#
#  tf.math.multiply_19 (TFOpL  (None,)                      0         ['tf.random.normal_19[0][0]']
#  ambda)
#
#  tf.__operators__.add_38 (T  (None,)                      0         ['tf.math.multiply_19[0][0]']
#  FOpLambda)
#
#  tf.convert_to_tensor_59 (T  (None,)                      0         ['tf.__operators__.add_38[0][0
#  FOpLambda)                                                         ]']
#
#  tf.compat.v1.shape_39 (TFO  (1,)                         0         ['tf.convert_to_tensor_59[0][0
#  pLambda)                                                           ]']
#
#  tf.convert_to_tensor_58 (T  (4,)                         0         ['tf.convert_to_tensor_57[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.getitem_1  (0,)                         0         ['tf.compat.v1.shape_39[0][0]'
#  9 (SlicingOpLambda)                                                ]
#
#  tf.concat_39 (TFOpLambda)   (4,)                         0         ['tf.convert_to_tensor_58[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.getitem_19[
#                                                                     0][0]']
#
#  tf.reshape_19 (TFOpLambda)  (None, 128, 128, 3)          0         ['tf.__operators__.add_38[0][0
#                                                                     ]',
#                                                                      'tf.concat_39[0][0]']
#
#  undamaged_input (InputLaye  [(None, 128, 128, 3)]        0         []
#  r)
#
#  tf.__operators__.add_39 (T  (None, 128, 128, 3)          0         ['tf.__operators__.add_37[0][0
#  FOpLambda)                                                         ]',
#                                                                      'tf.reshape_19[0][0]']
#
#  tf.__operators__.add_40 (T  (None, 128, 128, 3)          0         ['undamaged_input[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_39[0][0
#                                                                     ]']
#
# ==================================================================================================
# Total params: 0 (0.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# define the encoder part of inpainting model. The encoder_input is the input to model, and must two convolutional layers (encoder_conv1 and encoder_conv2) that be processed this input.
#
#
#
#
# add a new input for the mask (mask_input). The shape of mask_input is assumed to be the same as the input shape, except for the last dimension, which is set to 1. This assumes a grayscale mask. If your mask has three channels, adjust the shape accordingly. The masked_encoder_input is created by concatenating the original encoder_input and the mask_input along the channel axis using layers.Concatenate.
#
#
# define the decoder. It takes the masked_encoder_input and performs a transposed convolution (Conv2DTranspose) to upsample the features. Finally, a convolutional layer produces the final output (decoder_output) with 3 channels using the sigmoid activation function.
#
#
# The inpainting_model is created using the keras.Model class, taking both encoder_input and mask_input as inputs and producing decoder_output. The model summary is printed for inspection.

# %%
# Define the diffusion function using TensorFlow Probability
def diffusion_function(inputs):
    undamaged, damaged = inputs

    x = tf.concat([undamaged, damaged], axis=-1)
    x = BatchNormalization()(x)

    # Output layer
    diffusion_output = Dense(img_shape[-1], activation='tanh')(x)

    return diffusion_output

def build_diffusion_model():
    undamaged_input = Input(shape=img_shape, name='undamaged_input')
    damaged_input = Input(shape=img_shape, name='damaged_input')

    diffusion_output = diffusion_function([undamaged_input, damaged_input])

    repaired_output = undamaged_input + diffusion_output

    model = Model(inputs=[undamaged_input, damaged_input], outputs=repaired_output)
    model.summary()

    return model

# Clear TensorFlow session before training
tf.keras.backend.clear_session()

# Build and compile the repair model
repair_model = build_diffusion_model()
repair_model_optimizer = Adam(learning_rate=0.0002, beta_1=0.5, clipvalue=1.0)

repair_model.compile(loss='mse', optimizer=repair_model_optimizer)
# Out:
# Model: "inpainting_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 64)      1792
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 128)       73856
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 64)      73792
#  Transpose)
#
#  conv2d_8 (Conv2D)           (None, 128, 128, 3)       1731
#
# =================================================================
# Total params: 151171 (590.51 KB)
# Trainable params: 151171 (590.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Training Loop:
#
# Loops through epochs.
#
# Samples noise and generates repaired images using the repair model.
#
# Trains the repair model on the batch of undamaged and damaged images.
#
# Calculates quantitative metrics (PSNR and SSIM) between undamaged and repaired images.
#
# Prints repair progress, metrics, and saves generated images at specified intervals.

# %%
# Training loop for the repair model
for epoch in range(epochs):
    # Sample noise and generate a batch of repaired images using diffusion
    repaired_imgs = repair_model.predict([X_test_undamaged_testset_resized, X_test_damaged_testset_resized])

    # Train the repair model
    K.clear_session()  # Clear TensorFlow session to release memory
    repair_loss = repair_model.train_on_batch([X_test_undamaged_testset_resized, X_test_damaged_testset_resized], X_test_undamaged_testset_resized)

    # Rescale images to 0-1
    X_test_undamaged_rescaled = 0.5 * (X_test_undamaged_testset_resized + 1)
    X_test_damaged_rescaled = 0.5 * (X_test_damaged_testset_resized + 1)
    repaired_imgs_rescaled = 0.5 * (repaired_imgs + 1)


    # Print repair progress and metrics
    print(f"[Repair Epoch {epoch}/{epochs}] [Repair loss: {repair_loss}]")

    # Calculate and print metrics
    psnr_value, ssim_value = calculate_metrics(X_test_undamaged_rescaled, repaired_imgs_rescaled, win_size=3)
    print(f"[Quantitative Evaluation] [PSNR: {psnr_value}, SSIM: {ssim_value}]")

    # Save generated images at a specified interval
    if epoch % save_interval == 0:
        save_generated_images(epoch, repair_model, output_path, X_test_undamaged_testset, X_test_damaged_testset)
# Out:
# 135/135 [==============================] - 1s 6ms/step
# [Repair Epoch 0/1000] [Repair loss: 0.43653714656829834]
# [Quantitative Evaluation] [PSNR: 9.386246597028837, SSIM: 0.5821332004619051]
# 135/135 [==============================] - 1s 6ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 135/135 [==============================] - 1s 6ms/step
# [Repair Epoch 1/1000] [Repair loss: 0.4360705316066742]
# [Quantitative Evaluation] [PSNR: 9.396606056401476, SSIM: 0.5812405898659244]
# 135/135 [==============================] - 1s 6ms/step
# [Repair Epoch 2/1000] [Repair loss: 0.4356038570404053]
# [Quantitative Evaluation] [PSNR: 9.406835630671177, SSIM: 0.5803626849793121]
# 135/135 [==============================] - 1s 6ms/step
# [Repair Epoch 3/1000] [Repair loss: 0.4351373314857483]
# [Quantitative Evaluation] [PSNR: 9.416939108895974, SSIM: 0.5795007970384566]
# 135/135 [==============================] - 1s 6ms/step
# [Repair Epoch 4/1000] [Repair loss: 0.43467092514038086]
# [Quantitative Evaluation] [PSNR: 9.426921102584942, SSIM: 0.5786525917575577]
# 135/135 [==============================] - 1s 6ms/step
# [Repair Epoch 5/1000] [Repair loss: 0.434204638004303]
# [Quantitative Evaluation] [PSNR: 9.436785709767054, SSIM: 0.57781953882037]
# 135/135 [==============================] - 1s 5ms/step
# [Repair Epoch 6/1000] [Repair loss: 0.4337383210659027]
# [Quantitative Evaluation] [PSNR: 9.446536457868994, SSIM: 0.5770012398033937]
# 135/135 [==============================] - 1s 6ms/step
# [Repair Epoch 7/1000] [Repair loss: 0.43327224254608154]
# [Quantitative Evaluation] [PSNR: 9.456177302162601, SSIM: 0.5761975154620885]
# 135/135 [==============================] - 1s 6ms/step
# [Repair Epoch 8/1000] [Repair loss: 0.4328063428401947]
# [Quantitative Evaluation] [PSNR: 9.465711139089189, SSIM: 0.5754082328249569]
# 135/135 [==============================] - 1s 6ms/step
# [Repair Epoch 9/1000] [Repair loss: 0.43234050273895264]
# [Quantitative Evaluation] [PSNR: 9.475141966473915, SSIM: 0.5746329403075902]
# 135/135 [==============================] - 1s 6ms/step
# [Repair Epoch 10/1000] [Repair loss: 0.43187472224235535]
# [Quantitative Evaluation] [PSNR: 9.484472650920043, SSIM: 0.5738718035640278]
# 135/135 [==============================] - 1s 6ms/step
# [Repair Epoch 11/1000] [Repair loss: 0.4314090609550476]
# [Quantitative Evaluation] [PSNR: 9.493706373084246, SSIM: 0.5731241560850472]
# 135/135 [==============================] - 1s 6ms/step
# [Repair Epoch 12/1000] [Repair loss: 0.43094363808631897]
# [Quantitative Evaluation] [PSNR: 9.502846064802023, SSIM: 0.5723910672270641]
# 135/135 [==============================] - 1s 5ms/step
# [Repair Epoch 13/1000] [Repair loss: 0.4304782748222351]
# [Quantitative Evaluation] [PSNR: 9.511894546699999, SSIM: 0.5716711612369273]
# 135/135 [==============================] - 1s 6ms/step
# [Repair Epoch